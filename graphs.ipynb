# %%
# !pip install matplotlib ipympl
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib widget

# %%
D = np.loadtxt('./results/ga/ex1_whole[2023-02-27][15-08].txt', dtype=np.float32)
D.shape
# Out:
# (94, 25)

# %%
fig = plt.figure()
plt.plot(D.mean(axis=1), label="mean")
plt.plot(D.min(axis=1), label="min")
plt.plot(D.max(axis=1), label="max")
plt.legend()
display(fig)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
